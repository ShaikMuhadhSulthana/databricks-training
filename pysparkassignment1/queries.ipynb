# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaikMuhadhSulthana/databricks-training/blob/main/pysparkassignment1/queries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark

from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

spark = SparkSession.builder \
    .appName("PySpark Practice") \
    .getOrCreate()

# %%
data = [
    (1, "Sravan", 25, "Hyderabad", "Data Engineer", 55000, "2023-01-15", "IT"),
    (2, "Ravi", 28, "Bangalore", "Software Engineer", 72000, "2022-11-10", "IT"),
    (3, "Priya", 24, "Chennai", "Analyst", 48000, "2023-03-12", "Analytics"),
    (4, "Kiran", 30, "Pune", "Manager", 85000, "2021-09-20", "Management"),
    (5, "Sneha", 27, "Mumbai", "HR", 45000, "2020-05-18", "HR"),
    (6, "Arjun", 26, "Delhi", "Developer", 61000, "2022-07-25", "IT"),
    (7, "Meena", 29, "Hyderabad", "Tester", 53000, "2021-12-11", "QA"),
    (8, "Rahul", 31, "Bangalore", "Architect", 98000, "2019-10-14", "IT"),
    (9, "Pooja", 23, "Chennai", "Support", 40000, "2023-04-19", "Support"),
    (10, "Vikas", 32, "Pune", "Lead", 91000, "2018-06-30", "IT"),

    (11, "Anjali", 26, "Mumbai", "Recruiter", 47000, "2022-02-15", "HR"),
    (12, "Ramesh", 35, "Delhi", "Manager", 105000, "2017-03-11", "Management"),
    (13, "Divya", 24, "Hyderabad", "Analyst", 51000, "2023-06-01", "Analytics"),
    (14, "Suresh", 29, "Chennai", "Developer", 68000, "2021-01-21", "IT"),
    (15, "Lavanya", 27, "Pune", "Tester", 54000, "2020-08-08", "QA"),
    (16, "Mahesh", 33, "Bangalore", "Consultant", 87000, "2019-11-19", "Consulting"),
    (17, "Keerthi", 25, "Mumbai", "HR", 43000, "2022-09-14", "HR"),
    (18, "Naresh", 28, "Delhi", "Engineer", 62000, "2021-05-17", "IT"),
    (19, "Swathi", 26, "Hyderabad", "Developer", 64000, "2022-12-05", "IT"),
    (20, "Ajay", 34, "Chennai", "Lead", 93000, "2018-04-22", "IT"),

    (21, "Bhavana", 22, "Pune", "Intern", 25000, "2024-01-10", "Training"),
    (22, "Nikhil", 30, "Mumbai", "Architect", 99000, "2019-07-09", "IT"),
    (23, "Harsha", 27, "Delhi", "Analyst", 52000, "2022-03-13", "Analytics"),
    (24, "Deepika", 29, "Hyderabad", "Manager", 81000, "2020-10-29", "Management"),
    (25, "Tarun", 31, "Bangalore", "Developer", 71000, "2021-11-01", "IT"),
    (26, "Neha", 24, "Chennai", "Tester", 50000, "2023-02-18", "QA"),
    (27, "Rohit", 28, "Pune", "Support", 42000, "2022-06-25", "Support"),
    (28, "Sanjana", 26, "Mumbai", "Recruiter", 46000, "2021-07-07", "HR"),
    (29, "Manoj", 35, "Delhi", "Director", 120000, "2016-12-15", "Management"),
    (30, "Asha", 23, "Hyderabad", "Intern", 27000, "2024-02-05", "Training"),

    (31, "Vinay", 29, "Bangalore", "Engineer", 67000, "2020-09-19", "IT"),
    (32, "Kavya", 25, "Chennai", "Analyst", 49000, "2023-05-28", "Analytics"),
    (33, "Gopi", 32, "Pune", "Lead", 88000, "2019-01-11", "IT"),
    (34, "Ishita", 27, "Mumbai", "Developer", 69000, "2021-04-04", "IT"),
    (35, "Pradeep", 30, "Delhi", "Consultant", 82000, "2020-03-23", "Consulting"),
    (36, "Sowmya", 24, "Hyderabad", "Tester", 51000, "2022-08-18", "QA"),
    (37, "Chandu", 26, "Bangalore", "Support", 41000, "2023-01-30", "Support"),
    (38, "Nandini", 28, "Chennai", "HR", 44000, "2021-06-16", "HR"),
    (39, "Teja", 31, "Pune", "Architect", 101000, "2018-02-12", "IT"),
    (40, "Madhavi", 29, "Mumbai", "Manager", 83000, "2019-09-27", "Management"),

    (41, "Karthik", 27, "Delhi", "Developer", 73000, "2020-11-05", "IT"),
    (42, "Shilpa", 25, "Hyderabad", "Analyst", 53000, "2023-03-17", "Analytics"),
    (43, "Yash", 33, "Bangalore", "Director", 125000, "2017-08-08", "Management"),
    (44, "Reshma", 26, "Chennai", "Tester", 55000, "2022-10-20", "QA"),
    (45, "Abhi", 24, "Pune", "Intern", 26000, "2024-03-11", "Training"),
    (46, "Nikitha", 28, "Mumbai", "Developer", 70000, "2021-02-14", "IT"),
    (47, "Lokesh", 30, "Delhi", "Lead", 92000, "2019-05-26", "IT"),
    (48, "Anu", 23, "Hyderabad", "Support", 39000, "2023-07-01", "Support"),
    (49, "Sandeep", 34, "Bangalore", "Manager", 97000, "2018-08-15", "Management"),
    (50, "Pallavi", 27, "Chennai", "Engineer", 65000, "2020-12-09", "IT")
]

columns = [
    "emp_id",
    "emp_name",
    "age",
    "city",
    "designation",
    "salary",
    "joining_date",
    "department"
]

df = spark.createDataFrame(data, columns)

df.show(50, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# |9     |Pooja   |23 |Chennai  |Support          |40000 |2023-04-19  |Support   |
# ...

# %%
# 1. Select only emp_name and salary
df.select("emp_name", "salary").show(50,truncate=False)
# Out:
# +--------+------+
# |emp_name|salary|
# +--------+------+
# |Sravan  |55000 |
# |Ravi    |72000 |
# |Priya   |48000 |
# |Kiran   |85000 |
# |Sneha   |45000 |
# |Arjun   |61000 |
# |Meena   |53000 |
# |Rahul   |98000 |
# |Pooja   |40000 |
# |Vikas   |91000 |
# |Anjali  |47000 |
# |Ramesh  |105000|
# |Divya   |51000 |
# |Suresh  |68000 |
# |Lavanya |54000 |
# |Mahesh  |87000 |
# |Keerthi |43000 |
# |Naresh  |62000 |
# |Swathi  |64000 |
# |Ajay    |93000 |
# |Bhavana |25000 |
# |Nikhil  |99000 |
# |Harsha  |52000 |
# |Deepika |81000 |
# |Tarun   |71000 |
# |Neha    |50000 |
# |Rohit   |42000 |
# |Sanjana |46000 |
# |Manoj   |120000|
# |Asha    |27000 |
# |Vinay   |67000 |
# |Kavya   |49000 |
# |Gopi    |88000 |
# |Ishita  |69000 |
# |Pradeep |82000 |
# |Sowmya  |51000 |
# |Chandu  |41000 |
# |Nandini |44000 |
# |Teja    |101000|
# |Madhavi |83000 |
# |Karthik |73000 |
# |Shilpa  |53000 |
# |Yash    |125000|
# |Reshma  |55000 |
# |Abhi    |26000 |
# |Nikitha |70000 |
# |Lokesh  |92000 |
# ...

# %%
# 2. Select emp_id, emp_name, and department
df.select("emp_id", "emp_name", "department").show(50,truncate=False)
# Out:
# +------+--------+----------+
# |emp_id|emp_name|department|
# +------+--------+----------+
# |1     |Sravan  |IT        |
# |2     |Ravi    |IT        |
# |3     |Priya   |Analytics |
# |4     |Kiran   |Management|
# |5     |Sneha   |HR        |
# |6     |Arjun   |IT        |
# |7     |Meena   |QA        |
# |8     |Rahul   |IT        |
# |9     |Pooja   |Support   |
# |10    |Vikas   |IT        |
# |11    |Anjali  |HR        |
# |12    |Ramesh  |Management|
# |13    |Divya   |Analytics |
# |14    |Suresh  |IT        |
# |15    |Lavanya |QA        |
# |16    |Mahesh  |Consulting|
# |17    |Keerthi |HR        |
# |18    |Naresh  |IT        |
# |19    |Swathi  |IT        |
# |20    |Ajay    |IT        |
# |21    |Bhavana |Training  |
# |22    |Nikhil  |IT        |
# |23    |Harsha  |Analytics |
# |24    |Deepika |Management|
# |25    |Tarun   |IT        |
# |26    |Neha    |QA        |
# |27    |Rohit   |Support   |
# |28    |Sanjana |HR        |
# |29    |Manoj   |Management|
# ...

# %%
# 4. Select all employees from only IT department with selected columns
df.filter(df.department == "IT") \
  .select("emp_id", "emp_name", "designation", "salary") \
  .show(50,truncate=False)
# Out:
# +------+--------+-----------------+------+
# |emp_id|emp_name|designation      |salary|
# +------+--------+-----------------+------+
# |1     |Sravan  |Data Engineer    |55000 |
# |2     |Ravi    |Software Engineer|72000 |
# |6     |Arjun   |Developer        |61000 |
# |8     |Rahul   |Architect        |98000 |
# |10    |Vikas   |Lead             |91000 |
# |14    |Suresh  |Developer        |68000 |
# |18    |Naresh  |Engineer         |62000 |
# |19    |Swathi  |Developer        |64000 |
# |20    |Ajay    |Lead             |93000 |
# |22    |Nikhil  |Architect        |99000 |
# |25    |Tarun   |Developer        |71000 |
# |31    |Vinay   |Engineer         |67000 |
# |33    |Gopi    |Lead             |88000 |
# |34    |Ishita  |Developer        |69000 |
# |39    |Teja    |Architect        |101000|
# |41    |Karthik |Developer        |73000 |
# |46    |Nikitha |Developer        |70000 |
# |47    |Lokesh  |Lead             |92000 |
# |50    |Pallavi |Engineer         |65000 |
# ...

# %%
# 4. Select all employees from only IT department with selected columns
df.filter(df.department == "IT") \
  .select("emp_id", "emp_name", "designation", "salary") \
  .show(500, truncate=False)
# Out:
# +------+--------+-----------------+------+
# |emp_id|emp_name|designation      |salary|
# +------+--------+-----------------+------+
# |1     |Sravan  |Data Engineer    |55000 |
# |2     |Ravi    |Software Engineer|72000 |
# |6     |Arjun   |Developer        |61000 |
# |8     |Rahul   |Architect        |98000 |
# |10    |Vikas   |Lead             |91000 |
# |14    |Suresh  |Developer        |68000 |
# |18    |Naresh  |Engineer         |62000 |
# |19    |Swathi  |Developer        |64000 |
# |20    |Ajay    |Lead             |93000 |
# |22    |Nikhil  |Architect        |99000 |
# |25    |Tarun   |Developer        |71000 |
# |31    |Vinay   |Engineer         |67000 |
# |33    |Gopi    |Lead             |88000 |
# |34    |Ishita  |Developer        |69000 |
# |39    |Teja    |Architect        |101000|
# |41    |Karthik |Developer        |73000 |
# |46    |Nikitha |Developer        |70000 |
# |47    |Lokesh  |Lead             |92000 |
# |50    |Pallavi |Engineer         |65000 |
# ...

# %%
# 5. Select emp_name, joining_date, and salary
df.select("emp_name", "joining_date", "salary").show(500, truncate=False)
# Out:
# +--------+------------+------+
# |emp_name|joining_date|salary|
# +--------+------------+------+
# |Sravan  |2023-01-15  |55000 |
# |Ravi    |2022-11-10  |72000 |
# |Priya   |2023-03-12  |48000 |
# |Kiran   |2021-09-20  |85000 |
# |Sneha   |2020-05-18  |45000 |
# |Arjun   |2022-07-25  |61000 |
# |Meena   |2021-12-11  |53000 |
# |Rahul   |2019-10-14  |98000 |
# |Pooja   |2023-04-19  |40000 |
# |Vikas   |2018-06-30  |91000 |
# |Anjali  |2022-02-15  |47000 |
# |Ramesh  |2017-03-11  |105000|
# |Divya   |2023-06-01  |51000 |
# |Suresh  |2021-01-21  |68000 |
# |Lavanya |2020-08-08  |54000 |
# |Mahesh  |2019-11-19  |87000 |
# |Keerthi |2022-09-14  |43000 |
# |Naresh  |2021-05-17  |62000 |
# |Swathi  |2022-12-05  |64000 |
# |Ajay    |2018-04-22  |93000 |
# |Bhavana |2024-01-10  |25000 |
# |Nikhil  |2019-07-09  |99000 |
# |Harsha  |2022-03-13  |52000 |
# |Deepika |2020-10-29  |81000 |
# |Tarun   |2021-11-01  |71000 |
# |Neha    |2023-02-18  |50000 |
# |Rohit   |2022-06-25  |42000 |
# ...

# %%
# 6. Select first 5 columns from dataframe
df.select(df.columns[:5]).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+
# |emp_id|emp_name|age|city     |designation      |
# +------+--------+---+---------+-----------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |
# |2     |Ravi    |28 |Bangalore|Software Engineer|
# |3     |Priya   |24 |Chennai  |Analyst          |
# |4     |Kiran   |30 |Pune     |Manager          |
# |5     |Sneha   |27 |Mumbai   |HR               |
# |6     |Arjun   |26 |Delhi    |Developer        |
# |7     |Meena   |29 |Hyderabad|Tester           |
# |8     |Rahul   |31 |Bangalore|Architect        |
# |9     |Pooja   |23 |Chennai  |Support          |
# |10    |Vikas   |32 |Pune     |Lead             |
# |11    |Anjali  |26 |Mumbai   |Recruiter        |
# |12    |Ramesh  |35 |Delhi    |Manager          |
# |13    |Divya   |24 |Hyderabad|Analyst          |
# |14    |Suresh  |29 |Chennai  |Developer        |
# |15    |Lavanya |27 |Pune     |Tester           |
# |16    |Mahesh  |33 |Bangalore|Consultant       |
# ...

# %%
# 7. Select employees whose salary column only
df.select("salary").show(500, truncate=False)
# Out:
# +------+
# |salary|
# +------+
# |55000 |
# |72000 |
# |48000 |
# |85000 |
# |45000 |
# |61000 |
# |53000 |
# |98000 |
# |40000 |
# |91000 |
# |47000 |
# |105000|
# |51000 |
# |68000 |
# |54000 |
# |87000 |
# |43000 |
# |62000 |
# |64000 |
# |93000 |
# |25000 |
# |99000 |
# |52000 |
# |81000 |
# |71000 |
# |50000 |
# |42000 |
# |46000 |
# |120000|
# |27000 |
# |67000 |
# |49000 |
# |88000 |
# |69000 |
# |82000 |
# |51000 |
# |41000 |
# |44000 |
# |101000|
# |83000 |
# |73000 |
# |53000 |
# |125000|
# |55000 |
# |26000 |
# |70000 |
# |92000 |
# |39000 |
# |97000 |
# |65000 |
# +------+

# %%
# 8. Select emp_name and city for employees from Hyderabad
df.filter(df.city == "Hyderabad") \
  .select("emp_name", "city") \
  .show(500, truncate=False)
# Out:
# +--------+---------+
# |emp_name|city     |
# +--------+---------+
# |Sravan  |Hyderabad|
# |Meena   |Hyderabad|
# |Divya   |Hyderabad|
# |Swathi  |Hyderabad|
# |Deepika |Hyderabad|
# |Asha    |Hyderabad|
# |Sowmya  |Hyderabad|
# |Shilpa  |Hyderabad|
# |Anu     |Hyderabad|
# +--------+---------+

# %%
# 9. Select designation and department
df.select("designation", "department").show(500, truncate=False)
# Out:
# +-----------------+----------+
# |designation      |department|
# +-----------------+----------+
# |Data Engineer    |IT        |
# |Software Engineer|IT        |
# |Analyst          |Analytics |
# |Manager          |Management|
# |HR               |HR        |
# |Developer        |IT        |
# |Tester           |QA        |
# |Architect        |IT        |
# |Support          |Support   |
# |Lead             |IT        |
# |Recruiter        |HR        |
# |Manager          |Management|
# |Analyst          |Analytics |
# |Developer        |IT        |
# |Tester           |QA        |
# |Consultant       |Consulting|
# |HR               |HR        |
# |Engineer         |IT        |
# |Developer        |IT        |
# |Lead             |IT        |
# |Intern           |Training  |
# |Architect        |IT        |
# |Analyst          |Analytics |
# |Manager          |Management|
# |Developer        |IT        |
# |Tester           |QA        |
# |Support          |Support   |
# ...

# %%
# 10. Select all columns except joining_date
df.drop("joining_date").show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|department|
# +------+--------+---+---------+-----------------+------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |IT        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |Analytics |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |Management|
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |HR        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |IT        |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |QA        |
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |IT        |
# |9     |Pooja   |23 |Chennai  |Support          |40000 |Support   |
# |10    |Vikas   |32 |Pune     |Lead             |91000 |IT        |
# |11    |Anjali  |26 |Mumbai   |Recruiter        |47000 |HR        |
# ...

# %%
# 1. Display emp_name as employee_name
df.select(df.emp_name.alias("employee_name")) \
  .show(500, truncate=False)
# Out:
# +-------------+
# |employee_name|
# +-------------+
# |Sravan       |
# |Ravi         |
# |Priya        |
# |Kiran        |
# |Sneha        |
# |Arjun        |
# |Meena        |
# |Rahul        |
# |Pooja        |
# |Vikas        |
# |Anjali       |
# |Ramesh       |
# |Divya        |
# |Suresh       |
# |Lavanya      |
# |Mahesh       |
# |Keerthi      |
# |Naresh       |
# |Swathi       |
# |Ajay         |
# |Bhavana      |
# |Nikhil       |
# |Harsha       |
# |Deepika      |
# |Tarun        |
# |Neha         |
# |Rohit        |
# |Sanjana      |
# |Manoj        |
# |Asha         |
# |Vinay        |
# |Kavya        |
# |Gopi         |
# |Ishita       |
# |Pradeep      |
# |Sowmya       |
# |Chandu       |
# |Nandini      |
# |Teja         |
# |Madhavi      |
# |Karthik      |
# |Shilpa       |
# |Yash         |
# |Reshma       |
# |Abhi         |
# |Nikitha      |
# |Lokesh       |
# |Anu          |
# |Sandeep      |
# |Pallavi      |
# +-------------+

# %%
# 2. Display salary as monthly_salary
df.select(df.salary.alias("monthly_salary")) \
  .show(500, truncate=False)
# Out:
# +--------------+
# |monthly_salary|
# +--------------+
# |55000         |
# |72000         |
# |48000         |
# |85000         |
# |45000         |
# |61000         |
# |53000         |
# |98000         |
# |40000         |
# |91000         |
# |47000         |
# |105000        |
# |51000         |
# |68000         |
# |54000         |
# |87000         |
# |43000         |
# |62000         |
# |64000         |
# |93000         |
# |25000         |
# |99000         |
# |52000         |
# |81000         |
# |71000         |
# |50000         |
# |42000         |
# |46000         |
# |120000        |
# |27000         |
# |67000         |
# |49000         |
# |88000         |
# |69000         |
# |82000         |
# |51000         |
# |41000         |
# |44000         |
# |101000        |
# |83000         |
# |73000         |
# |53000         |
# |125000        |
# |55000         |
# |26000         |
# |70000         |
# |92000         |
# |39000         |
# |97000         |
# ...

# %%
# 3. Display department as dept
df.select(df.department.alias("dept")) \
  .show(500, truncate=False)
# Out:
# +----------+
# |dept      |
# +----------+
# |IT        |
# |IT        |
# |Analytics |
# |Management|
# |HR        |
# |IT        |
# |QA        |
# |IT        |
# |Support   |
# |IT        |
# |HR        |
# |Management|
# |Analytics |
# |IT        |
# |QA        |
# |Consulting|
# |HR        |
# |IT        |
# |IT        |
# |IT        |
# |Training  |
# |IT        |
# |Analytics |
# |Management|
# |IT        |
# |QA        |
# |Support   |
# |HR        |
# |Management|
# |Training  |
# |IT        |
# |Analytics |
# |IT        |
# |IT        |
# |Consulting|
# |QA        |
# |Support   |
# |HR        |
# |IT        |
# |Management|
# |IT        |
# |Analytics |
# |Management|
# |QA        |
# |Training  |
# |IT        |
# |IT        |
# |Support   |
# |Management|
# |IT        |
# +----------+

# %%
# 4. Display joining_date as doj
df.select(df.joining_date.alias("doj")) \
  .show(500, truncate=False)
# Out:
# +----------+
# |doj       |
# +----------+
# |2023-01-15|
# |2022-11-10|
# |2023-03-12|
# |2021-09-20|
# |2020-05-18|
# |2022-07-25|
# |2021-12-11|
# |2019-10-14|
# |2023-04-19|
# |2018-06-30|
# |2022-02-15|
# |2017-03-11|
# |2023-06-01|
# |2021-01-21|
# |2020-08-08|
# |2019-11-19|
# |2022-09-14|
# |2021-05-17|
# |2022-12-05|
# |2018-04-22|
# |2024-01-10|
# |2019-07-09|
# |2022-03-13|
# |2020-10-29|
# |2021-11-01|
# |2023-02-18|
# |2022-06-25|
# |2021-07-07|
# |2016-12-15|
# |2024-02-05|
# |2020-09-19|
# |2023-05-28|
# |2019-01-11|
# |2021-04-04|
# |2020-03-23|
# |2022-08-18|
# |2023-01-30|
# |2021-06-16|
# |2018-02-12|
# |2019-09-27|
# |2020-11-05|
# |2023-03-17|
# |2017-08-08|
# |2022-10-20|
# |2024-03-11|
# |2021-02-14|
# |2019-05-26|
# |2023-07-01|
# |2018-08-15|
# |2020-12-09|
# +----------+

# %%
# 5. Select emp_name as name and city as location
df.select(
    df.emp_name.alias("name"),
    df.city.alias("location")
).show(500, truncate=False)
# Out:
# +-------+---------+
# |name   |location |
# +-------+---------+
# |Sravan |Hyderabad|
# |Ravi   |Bangalore|
# |Priya  |Chennai  |
# |Kiran  |Pune     |
# |Sneha  |Mumbai   |
# |Arjun  |Delhi    |
# |Meena  |Hyderabad|
# |Rahul  |Bangalore|
# |Pooja  |Chennai  |
# |Vikas  |Pune     |
# |Anjali |Mumbai   |
# |Ramesh |Delhi    |
# |Divya  |Hyderabad|
# |Suresh |Chennai  |
# |Lavanya|Pune     |
# |Mahesh |Bangalore|
# |Keerthi|Mumbai   |
# |Naresh |Delhi    |
# |Swathi |Hyderabad|
# |Ajay   |Chennai  |
# |Bhavana|Pune     |
# |Nikhil |Mumbai   |
# |Harsha |Delhi    |
# |Deepika|Hyderabad|
# |Tarun  |Bangalore|
# |Neha   |Chennai  |
# |Rohit  |Pune     |
# |Sanjana|Mumbai   |
# |Manoj  |Delhi    |
# |Asha   |Hyderabad|
# |Vinay  |Bangalore|
# |Kavya  |Chennai  |
# |Gopi   |Pune     |
# |Ishita |Mumbai   |
# |Pradeep|Delhi    |
# |Sowmya |Hyderabad|
# |Chandu |Bangalore|
# |Nandini|Chennai  |
# |Teja   |Pune     |
# |Madhavi|Mumbai   |
# |Karthik|Delhi    |
# |Shilpa |Hyderabad|
# ...

# %%
# 6. Display designation as job_role
df.select(df.designation.alias("job_role")) \
  .show(500, truncate=False)
# Out:
# +-----------------+
# |job_role         |
# +-----------------+
# |Data Engineer    |
# |Software Engineer|
# |Analyst          |
# |Manager          |
# |HR               |
# |Developer        |
# |Tester           |
# |Architect        |
# |Support          |
# |Lead             |
# |Recruiter        |
# |Manager          |
# |Analyst          |
# |Developer        |
# |Tester           |
# |Consultant       |
# |HR               |
# |Engineer         |
# |Developer        |
# |Lead             |
# |Intern           |
# |Architect        |
# |Analyst          |
# |Manager          |
# |Developer        |
# |Tester           |
# |Support          |
# |Recruiter        |
# |Director         |
# |Intern           |
# |Engineer         |
# |Analyst          |
# |Lead             |
# |Developer        |
# |Consultant       |
# |Tester           |
# |Support          |
# |HR               |
# |Architect        |
# |Manager          |
# |Developer        |
# |Analyst          |
# ...

# %%
# 7. Display age as employee_age
df.select(df.age.alias("employee_age")) \
  .show(500, truncate=False)
# Out:
# +------------+
# |employee_age|
# +------------+
# |25          |
# |28          |
# |24          |
# |30          |
# |27          |
# |26          |
# |29          |
# |31          |
# |23          |
# |32          |
# |26          |
# |35          |
# |24          |
# |29          |
# |27          |
# |33          |
# |25          |
# |28          |
# |26          |
# |34          |
# |22          |
# |30          |
# |27          |
# |29          |
# |31          |
# |24          |
# |28          |
# |26          |
# |35          |
# |23          |
# |29          |
# |25          |
# |32          |
# |27          |
# |30          |
# |24          |
# |26          |
# |28          |
# |31          |
# |29          |
# |27          |
# |25          |
# |33          |
# |26          |
# |24          |
# |28          |
# |30          |
# |23          |
# |34          |
# |27          |
# +------------+

# %%
# 8. Select multiple columns using aliases
df.select(
    df.emp_id.alias("employee_id"),
    df.emp_name.alias("employee_name"),
    df.salary.alias("monthly_salary"),
    df.department.alias("dept")
).show(500, truncate=False)
# Out:
# +-----------+-------------+--------------+----------+
# |employee_id|employee_name|monthly_salary|dept      |
# +-----------+-------------+--------------+----------+
# |1          |Sravan       |55000         |IT        |
# |2          |Ravi         |72000         |IT        |
# |3          |Priya        |48000         |Analytics |
# |4          |Kiran        |85000         |Management|
# |5          |Sneha        |45000         |HR        |
# |6          |Arjun        |61000         |IT        |
# |7          |Meena        |53000         |QA        |
# |8          |Rahul        |98000         |IT        |
# |9          |Pooja        |40000         |Support   |
# |10         |Vikas        |91000         |IT        |
# |11         |Anjali       |47000         |HR        |
# |12         |Ramesh       |105000        |Management|
# |13         |Divya        |51000         |Analytics |
# |14         |Suresh       |68000         |IT        |
# ...

# %%
# 9. Display salary as emp_salary and department as emp_dept
df.select(
    df.salary.alias("emp_salary"),
    df.department.alias("emp_dept")
).show(500, truncate=False)
# Out:
# +----------+----------+
# |emp_salary|emp_dept  |
# +----------+----------+
# |55000     |IT        |
# |72000     |IT        |
# |48000     |Analytics |
# |85000     |Management|
# |45000     |HR        |
# |61000     |IT        |
# |53000     |QA        |
# |98000     |IT        |
# |40000     |Support   |
# |91000     |IT        |
# |47000     |HR        |
# |105000    |Management|
# |51000     |Analytics |
# |68000     |IT        |
# |54000     |QA        |
# |87000     |Consulting|
# |43000     |HR        |
# |62000     |IT        |
# |64000     |IT        |
# |93000     |IT        |
# |25000     |Training  |
# |99000     |IT        |
# |52000     |Analytics |
# |81000     |Management|
# |71000     |IT        |
# |50000     |QA        |
# |42000     |Support   |
# |46000     |HR        |
# |120000    |Management|
# |27000     |Training  |
# |67000     |IT        |
# |49000     |Analytics |
# |88000     |IT        |
# |69000     |IT        |
# |82000     |Consulting|
# ...

# %%
# 10. Display city as work_location
df.select(df.city.alias("work_location")) \
  .show(500, truncate=False)
# Out:
# +-------------+
# |work_location|
# +-------------+
# |Hyderabad    |
# |Bangalore    |
# |Chennai      |
# |Pune         |
# |Mumbai       |
# |Delhi        |
# |Hyderabad    |
# |Bangalore    |
# |Chennai      |
# |Pune         |
# |Mumbai       |
# |Delhi        |
# |Hyderabad    |
# |Chennai      |
# |Pune         |
# |Bangalore    |
# |Mumbai       |
# |Delhi        |
# |Hyderabad    |
# |Chennai      |
# |Pune         |
# |Mumbai       |
# |Delhi        |
# |Hyderabad    |
# |Bangalore    |
# |Chennai      |
# |Pune         |
# |Mumbai       |
# |Delhi        |
# |Hyderabad    |
# |Bangalore    |
# |Chennai      |
# |Pune         |
# |Mumbai       |
# |Delhi        |
# |Hyderabad    |
# |Bangalore    |
# |Chennai      |
# |Pune         |
# |Mumbai       |
# |Delhi        |
# |Hyderabad    |
# |Bangalore    |
# |Chennai      |
# |Pune         |
# |Mumbai       |
# |Delhi        |
# |Hyderabad    |
# |Bangalore    |
# |Chennai      |
# +-------------+

# %%
# 1. Filter employees whose salary is greater than 70000
df.filter(df.salary > 70000).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# |10    |Vikas   |32 |Pune     |Lead             |91000 |2018-06-30  |IT        |
# |12    |Ramesh  |35 |Delhi    |Manager          |105000|2017-03-11  |Management|
# |16    |Mahesh  |33 |Bangalore|Consultant       |87000 |2019-11-19  |Consulting|
# |20    |Ajay    |34 |Chennai  |Lead             |93000 |2018-04-22  |IT        |
# |22    |Nikhil  |30 |Mumbai   |Architect        |99000 |2019-07-09  |IT        |
# |24    |Deepika |29 |Hyderabad|Manager          |81000 |2020-10-29  |Management|
# ...

# %%
# 2. Filter employees from Hyderabad
df.filter(df.city == "Hyderabad").show(500, truncate=False)
# Out:
# +------+--------+---+---------+-------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation  |salary|joining_date|department|
# +------+--------+---+---------+-------------+------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer|55000 |2023-01-15  |IT        |
# |7     |Meena   |29 |Hyderabad|Tester       |53000 |2021-12-11  |QA        |
# |13    |Divya   |24 |Hyderabad|Analyst      |51000 |2023-06-01  |Analytics |
# |19    |Swathi  |26 |Hyderabad|Developer    |64000 |2022-12-05  |IT        |
# |24    |Deepika |29 |Hyderabad|Manager      |81000 |2020-10-29  |Management|
# |30    |Asha    |23 |Hyderabad|Intern       |27000 |2024-02-05  |Training  |
# |36    |Sowmya  |24 |Hyderabad|Tester       |51000 |2022-08-18  |QA        |
# |42    |Shilpa  |25 |Hyderabad|Analyst      |53000 |2023-03-17  |Analytics |
# |48    |Anu     |23 |Hyderabad|Support      |39000 |2023-07-01  |Support   |
# ...

# %%
# 3. Filter employees whose age is less than 25
df.filter(df.age < 25).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation|salary|joining_date|department|
# +------+--------+---+---------+-----------+------+------------+----------+
# |3     |Priya   |24 |Chennai  |Analyst    |48000 |2023-03-12  |Analytics |
# |9     |Pooja   |23 |Chennai  |Support    |40000 |2023-04-19  |Support   |
# |13    |Divya   |24 |Hyderabad|Analyst    |51000 |2023-06-01  |Analytics |
# |21    |Bhavana |22 |Pune     |Intern     |25000 |2024-01-10  |Training  |
# |26    |Neha    |24 |Chennai  |Tester     |50000 |2023-02-18  |QA        |
# |30    |Asha    |23 |Hyderabad|Intern     |27000 |2024-02-05  |Training  |
# |36    |Sowmya  |24 |Hyderabad|Tester     |51000 |2022-08-18  |QA        |
# |45    |Abhi    |24 |Pune     |Intern     |26000 |2024-03-11  |Training  |
# |48    |Anu     |23 |Hyderabad|Support    |39000 |2023-07-01  |Support   |
# ...

# %%
# 3. Filter employees whose age is less than 25
df.filter(df.age < 25).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation|salary|joining_date|department|
# +------+--------+---+---------+-----------+------+------------+----------+
# |3     |Priya   |24 |Chennai  |Analyst    |48000 |2023-03-12  |Analytics |
# |9     |Pooja   |23 |Chennai  |Support    |40000 |2023-04-19  |Support   |
# |13    |Divya   |24 |Hyderabad|Analyst    |51000 |2023-06-01  |Analytics |
# |21    |Bhavana |22 |Pune     |Intern     |25000 |2024-01-10  |Training  |
# |26    |Neha    |24 |Chennai  |Tester     |50000 |2023-02-18  |QA        |
# |30    |Asha    |23 |Hyderabad|Intern     |27000 |2024-02-05  |Training  |
# |36    |Sowmya  |24 |Hyderabad|Tester     |51000 |2022-08-18  |QA        |
# |45    |Abhi    |24 |Pune     |Intern     |26000 |2024-03-11  |Training  |
# |48    |Anu     |23 |Hyderabad|Support    |39000 |2023-07-01  |Support   |
# ...

# %%
# 5. Filter employees whose designation is Developer
df.filter(df.designation == "Developer").show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation|salary|joining_date|department|
# +------+--------+---+---------+-----------+------+------------+----------+
# |6     |Arjun   |26 |Delhi    |Developer  |61000 |2022-07-25  |IT        |
# |14    |Suresh  |29 |Chennai  |Developer  |68000 |2021-01-21  |IT        |
# |19    |Swathi  |26 |Hyderabad|Developer  |64000 |2022-12-05  |IT        |
# |25    |Tarun   |31 |Bangalore|Developer  |71000 |2021-11-01  |IT        |
# |34    |Ishita  |27 |Mumbai   |Developer  |69000 |2021-04-04  |IT        |
# |41    |Karthik |27 |Delhi    |Developer  |73000 |2020-11-05  |IT        |
# |46    |Nikitha |28 |Mumbai   |Developer  |70000 |2021-02-14  |IT        |
# +------+--------+---+---------+-----------+------+------------+----------+

# %%
# 6. Filter employees whose salary is between 50000 and 80000
df.filter((df.salary >= 50000) & (df.salary <= 80000)) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |
# |13    |Divya   |24 |Hyderabad|Analyst          |51000 |2023-06-01  |Analytics |
# |14    |Suresh  |29 |Chennai  |Developer        |68000 |2021-01-21  |IT        |
# |15    |Lavanya |27 |Pune     |Tester           |54000 |2020-08-08  |QA        |
# |18    |Naresh  |28 |Delhi    |Engineer         |62000 |2021-05-17  |IT        |
# |19    |Swathi  |26 |Hyderabad|Developer        |64000 |2022-12-05  |IT        |
# ...

# %%
# 7. Filter employees whose city is Bangalore
df.filter(df.city == "Bangalore").show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# |16    |Mahesh  |33 |Bangalore|Consultant       |87000 |2019-11-19  |Consulting|
# |25    |Tarun   |31 |Bangalore|Developer        |71000 |2021-11-01  |IT        |
# |31    |Vinay   |29 |Bangalore|Engineer         |67000 |2020-09-19  |IT        |
# |37    |Chandu  |26 |Bangalore|Support          |41000 |2023-01-30  |Support   |
# |43    |Yash    |33 |Bangalore|Director         |125000|2017-08-08  |Management|
# |49    |Sandeep |34 |Bangalore|Manager          |97000 |2018-08-15  |Management|
# +------+--------+---+---------+-----------------+------+------------+----------+

# %%
# 8. Filter employees who joined after 2022-01-01
df.filter(df.joining_date > "2022-01-01") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# |9     |Pooja   |23 |Chennai  |Support          |40000 |2023-04-19  |Support   |
# |11    |Anjali  |26 |Mumbai   |Recruiter        |47000 |2022-02-15  |HR        |
# |13    |Divya   |24 |Hyderabad|Analyst          |51000 |2023-06-01  |Analytics |
# |17    |Keerthi |25 |Mumbai   |HR               |43000 |2022-09-14  |HR        |
# |19    |Swathi  |26 |Hyderabad|Developer        |64000 |2022-12-05  |IT        |
# ...

# %%
# 9. Filter employees whose age is greater than 30
df.filter(df.age > 30).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation|salary|joining_date|department|
# +------+--------+---+---------+-----------+------+------------+----------+
# |8     |Rahul   |31 |Bangalore|Architect  |98000 |2019-10-14  |IT        |
# |10    |Vikas   |32 |Pune     |Lead       |91000 |2018-06-30  |IT        |
# |12    |Ramesh  |35 |Delhi    |Manager    |105000|2017-03-11  |Management|
# |16    |Mahesh  |33 |Bangalore|Consultant |87000 |2019-11-19  |Consulting|
# |20    |Ajay    |34 |Chennai  |Lead       |93000 |2018-04-22  |IT        |
# |25    |Tarun   |31 |Bangalore|Developer  |71000 |2021-11-01  |IT        |
# |29    |Manoj   |35 |Delhi    |Director   |120000|2016-12-15  |Management|
# |33    |Gopi    |32 |Pune     |Lead       |88000 |2019-01-11  |IT        |
# |39    |Teja    |31 |Pune     |Architect  |101000|2018-02-12  |IT        |
# ...

# %%
# 10. Filter employees whose salary is less than 50000
df.filter(df.salary < 50000).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation|salary|joining_date|department|
# +------+--------+---+---------+-----------+------+------------+----------+
# |3     |Priya   |24 |Chennai  |Analyst    |48000 |2023-03-12  |Analytics |
# |5     |Sneha   |27 |Mumbai   |HR         |45000 |2020-05-18  |HR        |
# |9     |Pooja   |23 |Chennai  |Support    |40000 |2023-04-19  |Support   |
# |11    |Anjali  |26 |Mumbai   |Recruiter  |47000 |2022-02-15  |HR        |
# |17    |Keerthi |25 |Mumbai   |HR         |43000 |2022-09-14  |HR        |
# |21    |Bhavana |22 |Pune     |Intern     |25000 |2024-01-10  |Training  |
# |27    |Rohit   |28 |Pune     |Support    |42000 |2022-06-25  |Support   |
# |28    |Sanjana |26 |Mumbai   |Recruiter  |46000 |2021-07-07  |HR        |
# |30    |Asha    |23 |Hyderabad|Intern     |27000 |2024-02-05  |Training  |
# ...

# %%
# 11. Filter employees from Chennai and salary greater than 60000
df.filter((df.city == "Chennai") & (df.salary > 60000)) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+-------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city   |designation|salary|joining_date|department|
# +------+--------+---+-------+-----------+------+------------+----------+
# |14    |Suresh  |29 |Chennai|Developer  |68000 |2021-01-21  |IT        |
# |20    |Ajay    |34 |Chennai|Lead       |93000 |2018-04-22  |IT        |
# |50    |Pallavi |27 |Chennai|Engineer   |65000 |2020-12-09  |IT        |
# +------+--------+---+-------+-----------+------+------------+----------+

# %%
# 12. Filter employees from Mumbai or Pune
df.filter((df.city == "Mumbai") | (df.city == "Pune")) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city  |designation|salary|joining_date|department|
# +------+--------+---+------+-----------+------+------------+----------+
# |4     |Kiran   |30 |Pune  |Manager    |85000 |2021-09-20  |Management|
# |5     |Sneha   |27 |Mumbai|HR         |45000 |2020-05-18  |HR        |
# |10    |Vikas   |32 |Pune  |Lead       |91000 |2018-06-30  |IT        |
# |11    |Anjali  |26 |Mumbai|Recruiter  |47000 |2022-02-15  |HR        |
# |15    |Lavanya |27 |Pune  |Tester     |54000 |2020-08-08  |QA        |
# |17    |Keerthi |25 |Mumbai|HR         |43000 |2022-09-14  |HR        |
# |21    |Bhavana |22 |Pune  |Intern     |25000 |2024-01-10  |Training  |
# |22    |Nikhil  |30 |Mumbai|Architect  |99000 |2019-07-09  |IT        |
# |27    |Rohit   |28 |Pune  |Support    |42000 |2022-06-25  |Support   |
# |28    |Sanjana |26 |Mumbai|Recruiter  |46000 |2021-07-07  |HR        |
# ...

# %%
# 13. Filter employees whose name starts with 'S'
df.filter(df.emp_name.startswith("S")) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation  |salary|joining_date|department|
# +------+--------+---+---------+-------------+------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer|55000 |2023-01-15  |IT        |
# |5     |Sneha   |27 |Mumbai   |HR           |45000 |2020-05-18  |HR        |
# |14    |Suresh  |29 |Chennai  |Developer    |68000 |2021-01-21  |IT        |
# |19    |Swathi  |26 |Hyderabad|Developer    |64000 |2022-12-05  |IT        |
# |28    |Sanjana |26 |Mumbai   |Recruiter    |46000 |2021-07-07  |HR        |
# |36    |Sowmya  |24 |Hyderabad|Tester       |51000 |2022-08-18  |QA        |
# |42    |Shilpa  |25 |Hyderabad|Analyst      |53000 |2023-03-17  |Analytics |
# |49    |Sandeep |34 |Bangalore|Manager      |97000 |2018-08-15  |Management|
# +------+--------+---+---------+-------------+------+------------+----------+

# %%
# 14. Filter employees whose name ends with 'a'
df.filter(df.emp_name.endswith("a")) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation|salary|joining_date|department|
# +------+--------+---+---------+-----------+------+------------+----------+
# |3     |Priya   |24 |Chennai  |Analyst    |48000 |2023-03-12  |Analytics |
# |5     |Sneha   |27 |Mumbai   |HR         |45000 |2020-05-18  |HR        |
# |7     |Meena   |29 |Hyderabad|Tester     |53000 |2021-12-11  |QA        |
# |9     |Pooja   |23 |Chennai  |Support    |40000 |2023-04-19  |Support   |
# |13    |Divya   |24 |Hyderabad|Analyst    |51000 |2023-06-01  |Analytics |
# |15    |Lavanya |27 |Pune     |Tester     |54000 |2020-08-08  |QA        |
# |21    |Bhavana |22 |Pune     |Intern     |25000 |2024-01-10  |Training  |
# |23    |Harsha  |27 |Delhi    |Analyst    |52000 |2022-03-13  |Analytics |
# |24    |Deepika |29 |Hyderabad|Manager    |81000 |2020-10-29  |Management|
# ...

# %%
# 15. Filter employees whose department is HR
df.filter(df.department == "HR") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+-------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city   |designation|salary|joining_date|department|
# +------+--------+---+-------+-----------+------+------------+----------+
# |5     |Sneha   |27 |Mumbai |HR         |45000 |2020-05-18  |HR        |
# |11    |Anjali  |26 |Mumbai |Recruiter  |47000 |2022-02-15  |HR        |
# |17    |Keerthi |25 |Mumbai |HR         |43000 |2022-09-14  |HR        |
# |28    |Sanjana |26 |Mumbai |Recruiter  |46000 |2021-07-07  |HR        |
# |38    |Nandini |28 |Chennai|HR         |44000 |2021-06-16  |HR        |
# +------+--------+---+-------+-----------+------+------------+----------+

# %%
# 16. Filter employees whose designation contains 'Engineer'
df.filter(df.designation.contains("Engineer")) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |18    |Naresh  |28 |Delhi    |Engineer         |62000 |2021-05-17  |IT        |
# |31    |Vinay   |29 |Bangalore|Engineer         |67000 |2020-09-19  |IT        |
# |50    |Pallavi |27 |Chennai  |Engineer         |65000 |2020-12-09  |IT        |
# +------+--------+---+---------+-----------------+------+------------+----------+

# %%
# 17. Filter employees whose city is not Hyderabad
df.filter(df.city != "Hyderabad") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# |9     |Pooja   |23 |Chennai  |Support          |40000 |2023-04-19  |Support   |
# |10    |Vikas   |32 |Pune     |Lead             |91000 |2018-06-30  |IT        |
# |11    |Anjali  |26 |Mumbai   |Recruiter        |47000 |2022-02-15  |HR        |
# ...

# %%
# 18. Filter employees aged between 25 and 30
df.filter((df.age >= 25) & (df.age <= 30)) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |
# |11    |Anjali  |26 |Mumbai   |Recruiter        |47000 |2022-02-15  |HR        |
# |14    |Suresh  |29 |Chennai  |Developer        |68000 |2021-01-21  |IT        |
# |15    |Lavanya |27 |Pune     |Tester           |54000 |2020-08-08  |QA        |
# ...

# %%
# 19. Filter employees with salary greater than 90000
df.filter(df.salary > 90000) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation|salary|joining_date|department|
# +------+--------+---+---------+-----------+------+------------+----------+
# |8     |Rahul   |31 |Bangalore|Architect  |98000 |2019-10-14  |IT        |
# |10    |Vikas   |32 |Pune     |Lead       |91000 |2018-06-30  |IT        |
# |12    |Ramesh  |35 |Delhi    |Manager    |105000|2017-03-11  |Management|
# |20    |Ajay    |34 |Chennai  |Lead       |93000 |2018-04-22  |IT        |
# |22    |Nikhil  |30 |Mumbai   |Architect  |99000 |2019-07-09  |IT        |
# |29    |Manoj   |35 |Delhi    |Director   |120000|2016-12-15  |Management|
# |39    |Teja    |31 |Pune     |Architect  |101000|2018-02-12  |IT        |
# |43    |Yash    |33 |Bangalore|Director   |125000|2017-08-08  |Management|
# |47    |Lokesh  |30 |Delhi    |Lead       |92000 |2019-05-26  |IT        |
# ...

# %%
# 20. Filter employees from Support department
df.filter(df.department == "Support") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation|salary|joining_date|department|
# +------+--------+---+---------+-----------+------+------------+----------+
# |9     |Pooja   |23 |Chennai  |Support    |40000 |2023-04-19  |Support   |
# |27    |Rohit   |28 |Pune     |Support    |42000 |2022-06-25  |Support   |
# |37    |Chandu  |26 |Bangalore|Support    |41000 |2023-01-30  |Support   |
# |48    |Anu     |23 |Hyderabad|Support    |39000 |2023-07-01  |Support   |
# +------+--------+---+---------+-----------+------+------------+----------+

# %%
# 1. Rename emp_name to employee_name
df.withColumnRenamed("emp_name", "employee_name") \
  .show(500, truncate=False)
# Out:
# +------+-------------+---+---------+-----------------+------+------------+----------+
# |emp_id|employee_name|age|city     |designation      |salary|joining_date|department|
# +------+-------------+---+---------+-----------------+------+------------+----------+
# |1     |Sravan       |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |
# |2     |Ravi         |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |3     |Priya        |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |
# |4     |Kiran        |30 |Pune     |Manager          |85000 |2021-09-20  |Management|
# |5     |Sneha        |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |
# |6     |Arjun        |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# |7     |Meena        |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |
# |8     |Rahul        |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# ...

# %%
# 2. Rename department to dept
df.withColumnRenamed("department", "dept") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|dept      |
# +------+--------+---+---------+-----------------+------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# |9     |Pooja   |23 |Chennai  |Support          |40000 |2023-04-19  |Support   |
# ...

# %%
# 3. Rename joining_date to doj
df.withColumnRenamed("joining_date", "doj") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+----------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|doj       |department|
# +------+--------+---+---------+-----------------+------+----------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15|IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10|IT        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12|Analytics |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20|Management|
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18|HR        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25|IT        |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11|QA        |
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14|IT        |
# |9     |Pooja   |23 |Chennai  |Support          |40000 |2023-04-19|Support   |
# ...

# %%
# 4. Rename salary to monthly_salary
df.withColumnRenamed("salary", "monthly_salary") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+--------------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |monthly_salary|joining_date|department|
# +------+--------+---+---------+-----------------+--------------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000         |2023-01-15  |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000         |2022-11-10  |IT        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000         |2023-03-12  |Analytics |
# |4     |Kiran   |30 |Pune     |Manager          |85000         |2021-09-20  |Management|
# |5     |Sneha   |27 |Mumbai   |HR               |45000         |2020-05-18  |HR        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000         |2022-07-25  |IT        |
# |7     |Meena   |29 |Hyderabad|Tester           |53000         |2021-12-11  |QA        |
# ...

# %%
# 4. Rename salary to monthly_salary
df.withColumnRenamed("salary", "monthly_salary") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+--------------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |monthly_salary|joining_date|department|
# +------+--------+---+---------+-----------------+--------------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000         |2023-01-15  |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000         |2022-11-10  |IT        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000         |2023-03-12  |Analytics |
# |4     |Kiran   |30 |Pune     |Manager          |85000         |2021-09-20  |Management|
# |5     |Sneha   |27 |Mumbai   |HR               |45000         |2020-05-18  |HR        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000         |2022-07-25  |IT        |
# |7     |Meena   |29 |Hyderabad|Tester           |53000         |2021-12-11  |QA        |
# ...

# %%
# 4. Rename salary to monthly_salary
df.withColumnRenamed("salary", "monthly_salary") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+--------------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |monthly_salary|joining_date|department|
# +------+--------+---+---------+-----------------+--------------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000         |2023-01-15  |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000         |2022-11-10  |IT        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000         |2023-03-12  |Analytics |
# |4     |Kiran   |30 |Pune     |Manager          |85000         |2021-09-20  |Management|
# |5     |Sneha   |27 |Mumbai   |HR               |45000         |2020-05-18  |HR        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000         |2022-07-25  |IT        |
# |7     |Meena   |29 |Hyderabad|Tester           |53000         |2021-12-11  |QA        |
# ...

# %%
# 7. Rename age to employee_age
df.withColumnRenamed("age", "employee_age") \
  .show(500, truncate=False)
# Out:
# +------+--------+------------+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|employee_age|city     |designation      |salary|joining_date|department|
# +------+--------+------------+---------+-----------------+------+------------+----------+
# |1     |Sravan  |25          |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |
# |2     |Ravi    |28          |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |3     |Priya   |24          |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |
# |4     |Kiran   |30          |Pune     |Manager          |85000 |2021-09-20  |Management|
# |5     |Sneha   |27          |Mumbai   |HR               |45000 |2020-05-18  |HR        |
# |6     |Arjun   |26          |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# |7     |Meena   |29          |Hyderabad|Tester           |53000 |2021-12-11  |QA        |
# ...

# %%
# 8. Rename multiple columns one by one
df.withColumnRenamed("emp_name", "employee_name") \
  .withColumnRenamed("salary", "monthly_salary") \
  .withColumnRenamed("department", "dept") \
  .show(500, truncate=False)
# Out:
# +------+-------------+---+---------+-----------------+--------------+------------+----------+
# |emp_id|employee_name|age|city     |designation      |monthly_salary|joining_date|dept      |
# +------+-------------+---+---------+-----------------+--------------+------------+----------+
# |1     |Sravan       |25 |Hyderabad|Data Engineer    |55000         |2023-01-15  |IT        |
# |2     |Ravi         |28 |Bangalore|Software Engineer|72000         |2022-11-10  |IT        |
# |3     |Priya        |24 |Chennai  |Analyst          |48000         |2023-03-12  |Analytics |
# |4     |Kiran        |30 |Pune     |Manager          |85000         |2021-09-20  |Management|
# |5     |Sneha        |27 |Mumbai   |HR               |45000         |2020-05-18  |HR        |
# |6     |Arjun        |26 |Delhi    |Developer        |61000         |2022-07-25  |IT        |
# |7     |Meena        |29 |Hyderabad|Tester           |53000         |2021-12-11  |QA        |
# ...

# %%
# 9. Rename emp_id to employee_id
df.withColumnRenamed("emp_id", "employee_id") \
  .show(500, truncate=False)
# Out:
# +-----------+--------+---+---------+-----------------+------+------------+----------+
# |employee_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +-----------+--------+---+---------+-----------------+------+------------+----------+
# |1          |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |
# |2          |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |3          |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |
# |4          |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|
# |5          |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |
# |6          |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# |7          |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |
# |8          |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# ...

# %%
# 10. Rename department to business_unit
df.withColumnRenamed("department", "business_unit") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+-------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|business_unit|
# +------+--------+---+---------+-----------------+------+------------+-------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT           |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT           |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics    |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management   |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR           |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT           |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA           |
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT           |
# ...

# %%
# WITHCOLUMN
# 1. Create bonus column as 10% of salary
df.withColumn("bonus", df.salary * 0.10) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+-------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|bonus  |
# +------+--------+---+---------+-----------------+------+------------+----------+-------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |5500.0 |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |7200.0 |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |4800.0 |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|8500.0 |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |4500.0 |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |6100.0 |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |5300.0 |
# ...

# %%
# WITHCOLUMN
# 1. Create bonus column as 10% of salary
df.withColumn("bonus", df.salary * 0.10) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+-------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|bonus  |
# +------+--------+---+---------+-----------------+------+------------+----------+-------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |5500.0 |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |7200.0 |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |4800.0 |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|8500.0 |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |4500.0 |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |6100.0 |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |5300.0 |
# ...

# %%
# WITHCOLUMN
# 1. Create bonus column as 10% of salary
df.withColumn("bonus", df.salary * 0.10) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+-------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|bonus  |
# +------+--------+---+---------+-----------------+------+------------+----------+-------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |5500.0 |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |7200.0 |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |4800.0 |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|8500.0 |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |4500.0 |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |6100.0 |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |5300.0 |
# ...

# %%
# 4. Create updated_salary by adding 5000
df.withColumn("updated_salary", df.salary + 5000) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+--------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|updated_salary|
# +------+--------+---+---------+-----------------+------+------------+----------+--------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |60000         |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |77000         |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |53000         |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|90000         |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |50000         |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |66000         |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |58000         |
# ...

# %%
# 5. Create salary_category column
from pyspark.sql.functions import when

df.withColumn(
    "salary_category",
    when(df.salary >= 90000, "High")
    .when(df.salary >= 50000, "Medium")
    .otherwise("Low")
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+---------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|salary_category|
# +------+--------+---+---------+-----------------+------+------------+----------+---------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |Medium         |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |Medium         |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |Low            |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|Medium         |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |Low            |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |Medium         |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |Medium         |
# ...

# %%
# 5. Create salary_category column
from pyspark.sql.functions import when

df.withColumn(
    "salary_category",
    when(df.salary >= 90000, "High")
    .when(df.salary >= 50000, "Medium")
    .otherwise("Low")
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+---------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|salary_category|
# +------+--------+---+---------+-----------------+------+------------+----------+---------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |Medium         |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |Medium         |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |Low            |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|Medium         |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |Low            |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |Medium         |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |Medium         |
# ...

# %%
# 7. Create location column by combining city and department
from pyspark.sql.functions import concat_ws

df.withColumn(
    "location",
    concat_ws("-", df.city, df.department)
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+--------------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|location            |
# +------+--------+---+---------+-----------------+------+------------+----------+--------------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |Hyderabad-IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |Bangalore-IT        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |Chennai-Analytics   |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|Pune-Management     |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |Mumbai-HR           |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |Delhi-IT            |
# ...

# %%
# 8. Create increment_salary column with 15% hike
df.withColumn(
    "increment_salary",
    df.salary * 1.15
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+------------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|increment_salary  |
# +------+--------+---+---------+-----------------+------+------------+----------+------------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |63249.99999999999 |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |82800.0           |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |55199.99999999999 |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|97749.99999999999 |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |51749.99999999999 |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |70150.0           |
# ...

# %%
# 9. Create experience_status column based on joining year
from pyspark.sql.functions import year

df.withColumn(
    "experience_status",
    when(year("joining_date") < 2021, "Experienced")
    .otherwise("New")
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+-----------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|experience_status|
# +------+--------+---+---------+-----------------+------+------------+----------+-----------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |New              |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |New              |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |New              |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|New              |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |Experienced      |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |New              |
# ...

# %%
# 10. Create name_length column using employee name
from pyspark.sql.functions import length

df.withColumn(
    "name_length",
    length(df.emp_name)
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+-----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|name_length|
# +------+--------+---+---------+-----------------+------+------------+----------+-----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |6          |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |4          |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |5          |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|5          |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |5          |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |5          |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |5          |
# ...

# %%
# 11. Create is_high_salary column using condition
df.withColumn(
    "is_high_salary",
    when(df.salary > 80000, True).otherwise(False)
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+--------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|is_high_salary|
# +------+--------+---+---------+-----------------+------+------------+----------+--------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |false         |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |false         |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |false         |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|true          |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |false         |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |false         |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |false         |
# ...

# %%
# 11. Create is_high_salary column using condition
df.withColumn(
    "is_high_salary",
    when(df.salary > 80000, True).otherwise(False)
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+--------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|is_high_salary|
# +------+--------+---+---------+-----------------+------+------------+----------+--------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |false         |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |false         |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |false         |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|true          |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |false         |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |false         |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |false         |
# ...

# %%
# 13. Create salary_after_tax column
df.withColumn(
    "salary_after_tax",
    df.salary - (df.salary * 0.05)
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+----------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|salary_after_tax|
# +------+--------+---+---------+-----------------+------+------------+----------+----------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |52250.0         |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |68400.0         |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |45600.0         |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|80750.0         |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |42750.0         |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |57950.0         |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |50350.0         |
# ...

# %%
# 14. Create department_code column
df.withColumn(
    "department_code",
    substring(df.department, 1, 3)
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+---------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|department_code|
# +------+--------+---+---------+-----------------+------+------------+----------+---------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |IT             |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |IT             |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |Ana            |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|Man            |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |HR             |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |IT             |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |QA             |
# ...

# %%
# 15. Create double_salary column
df.withColumn(
    "double_salary",
    df.salary * 2
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+-------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|double_salary|
# +------+--------+---+---------+-----------------+------+------------+----------+-------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |110000       |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |144000       |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |96000        |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|170000       |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |90000        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |122000       |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |106000       |
# ...

# %%
# TYPECASTING
# 1. Convert salary to string datatype
df.withColumn(
    "salary_string",
    df.salary.cast("string")
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+-------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|salary_string|
# +------+--------+---+---------+-----------------+------+------------+----------+-------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |55000        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |72000        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |48000        |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|85000        |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |45000        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |61000        |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |53000        |
# ...

# %%
# 2. Convert age to double datatype
df.withColumn(
    "age_double",
    df.age.cast("double")
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|age_double|
# +------+--------+---+---------+-----------------+------+------------+----------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |25.0      |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |28.0      |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |24.0      |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|30.0      |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |27.0      |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |26.0      |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |29.0      |
# ...

# %%
# 3. Convert joining_date to date datatype
df.withColumn(
    "joining_date_new",
    df.joining_date.cast("date")
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+----------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|joining_date_new|
# +------+--------+---+---------+-----------------+------+------------+----------+----------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |2023-01-15      |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |2022-11-10      |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |2023-03-12      |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|2021-09-20      |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |2020-05-18      |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |2022-07-25      |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |2021-12-11      |
# ...

# %%
# 4. Convert emp_id to string datatype
df.withColumn(
    "emp_id_string",
    df.emp_id.cast("string")
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+-------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|emp_id_string|
# +------+--------+---+---------+-----------------+------+------------+----------+-------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |1            |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |2            |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |3            |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|4            |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |5            |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |6            |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |7            |
# ...

# %%
# 5. Convert salary to integer datatype
df.withColumn(
    "salary_int",
    df.salary.cast("int")
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|salary_int|
# +------+--------+---+---------+-----------------+------+------------+----------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |55000     |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |72000     |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |48000     |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|85000     |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |45000     |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |61000     |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |53000     |
# ...

# %%
# 6. Convert age to string datatype
df.withColumn(
    "age_string",
    df.age.cast("string")
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|age_string|
# +------+--------+---+---------+-----------------+------+------------+----------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |25        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |28        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |24        |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|30        |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |27        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |26        |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |29        |
# ...

# %%
# 7. Convert joining_date to timestamp datatype
df.withColumn(
    "joining_timestamp",
    df.joining_date.cast("timestamp")
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+-------------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|joining_timestamp  |
# +------+--------+---+---------+-----------------+------+------------+----------+-------------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |2023-01-15 00:00:00|
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |2022-11-10 00:00:00|
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |2023-03-12 00:00:00|
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|2021-09-20 00:00:00|
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |2020-05-18 00:00:00|
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |2022-07-25 00:00:00|
# ...

# %%
# 8. Convert salary to float datatype
df.withColumn(
    "salary_float",
    df.salary.cast("float")
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|salary_float|
# +------+--------+---+---------+-----------------+------+------------+----------+------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |55000.0     |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |72000.0     |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |48000.0     |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|85000.0     |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |45000.0     |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |61000.0     |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |53000.0     |
# ...

# %%
# 9. Convert emp_id to long datatype
df.withColumn(
    "emp_id_long",
    df.emp_id.cast("long")
).show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+-----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|emp_id_long|
# +------+--------+---+---------+-----------------+------+------------+----------+-----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |1          |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |2          |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |3          |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|4          |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |5          |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |6          |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |7          |
# ...

# %%
# 10. Convert multiple columns into different datatypes
df.withColumn("salary_string", df.salary.cast("string")) \
  .withColumn("age_double", df.age.cast("double")) \
  .withColumn("joining_date_new", df.joining_date.cast("date")) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+-------------+----------+----------------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|salary_string|age_double|joining_date_new|
# +------+--------+---+---------+-----------------+------+------------+----------+-------------+----------+----------------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |55000        |25.0      |2023-01-15      |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |72000        |28.0      |2022-11-10      |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |48000        |24.0      |2023-03-12      |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|85000        |30.0      |2021-09-20      |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |45000        |27.0      |2020-05-18      |
# ...

# %%
# SORT / ORDERBY
# 1. Sort employees by salary ascending
df.orderBy("salary") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |21    |Bhavana |22 |Pune     |Intern           |25000 |2024-01-10  |Training  |
# |45    |Abhi    |24 |Pune     |Intern           |26000 |2024-03-11  |Training  |
# |30    |Asha    |23 |Hyderabad|Intern           |27000 |2024-02-05  |Training  |
# |48    |Anu     |23 |Hyderabad|Support          |39000 |2023-07-01  |Support   |
# |9     |Pooja   |23 |Chennai  |Support          |40000 |2023-04-19  |Support   |
# |37    |Chandu  |26 |Bangalore|Support          |41000 |2023-01-30  |Support   |
# |27    |Rohit   |28 |Pune     |Support          |42000 |2022-06-25  |Support   |
# |17    |Keerthi |25 |Mumbai   |HR               |43000 |2022-09-14  |HR        |
# |38    |Nandini |28 |Chennai  |HR               |44000 |2021-06-16  |HR        |
# ...

# %%
# 2. Sort employees by salary descending
df.orderBy(df.salary.desc()) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |43    |Yash    |33 |Bangalore|Director         |125000|2017-08-08  |Management|
# |29    |Manoj   |35 |Delhi    |Director         |120000|2016-12-15  |Management|
# |12    |Ramesh  |35 |Delhi    |Manager          |105000|2017-03-11  |Management|
# |39    |Teja    |31 |Pune     |Architect        |101000|2018-02-12  |IT        |
# |22    |Nikhil  |30 |Mumbai   |Architect        |99000 |2019-07-09  |IT        |
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# |49    |Sandeep |34 |Bangalore|Manager          |97000 |2018-08-15  |Management|
# |20    |Ajay    |34 |Chennai  |Lead             |93000 |2018-04-22  |IT        |
# |47    |Lokesh  |30 |Delhi    |Lead             |92000 |2019-05-26  |IT        |
# ...

# %%
# 2. Sort employees by salary descending
df.orderBy(df.salary.desc()) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |43    |Yash    |33 |Bangalore|Director         |125000|2017-08-08  |Management|
# |29    |Manoj   |35 |Delhi    |Director         |120000|2016-12-15  |Management|
# |12    |Ramesh  |35 |Delhi    |Manager          |105000|2017-03-11  |Management|
# |39    |Teja    |31 |Pune     |Architect        |101000|2018-02-12  |IT        |
# |22    |Nikhil  |30 |Mumbai   |Architect        |99000 |2019-07-09  |IT        |
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# |49    |Sandeep |34 |Bangalore|Manager          |97000 |2018-08-15  |Management|
# |20    |Ajay    |34 |Chennai  |Lead             |93000 |2018-04-22  |IT        |
# |47    |Lokesh  |30 |Delhi    |Lead             |92000 |2019-05-26  |IT        |
# ...

# %%
# 4. Sort employees by emp_name ascending
df.orderBy("emp_name") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |45    |Abhi    |24 |Pune     |Intern           |26000 |2024-03-11  |Training  |
# |20    |Ajay    |34 |Chennai  |Lead             |93000 |2018-04-22  |IT        |
# |11    |Anjali  |26 |Mumbai   |Recruiter        |47000 |2022-02-15  |HR        |
# |48    |Anu     |23 |Hyderabad|Support          |39000 |2023-07-01  |Support   |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# |30    |Asha    |23 |Hyderabad|Intern           |27000 |2024-02-05  |Training  |
# |21    |Bhavana |22 |Pune     |Intern           |25000 |2024-01-10  |Training  |
# |37    |Chandu  |26 |Bangalore|Support          |41000 |2023-01-30  |Support   |
# |24    |Deepika |29 |Hyderabad|Manager          |81000 |2020-10-29  |Management|
# ...

# %%
# 5. Sort employees by city and salary descending
df.orderBy("city", df.salary.desc()) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |43    |Yash    |33 |Bangalore|Director         |125000|2017-08-08  |Management|
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# |49    |Sandeep |34 |Bangalore|Manager          |97000 |2018-08-15  |Management|
# |16    |Mahesh  |33 |Bangalore|Consultant       |87000 |2019-11-19  |Consulting|
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |25    |Tarun   |31 |Bangalore|Developer        |71000 |2021-11-01  |IT        |
# |31    |Vinay   |29 |Bangalore|Engineer         |67000 |2020-09-19  |IT        |
# |37    |Chandu  |26 |Bangalore|Support          |41000 |2023-01-30  |Support   |
# |20    |Ajay    |34 |Chennai  |Lead             |93000 |2018-04-22  |IT        |
# ...

# %%
# 6. Sort employees by joining_date
df.orderBy("joining_date") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |29    |Manoj   |35 |Delhi    |Director         |120000|2016-12-15  |Management|
# |12    |Ramesh  |35 |Delhi    |Manager          |105000|2017-03-11  |Management|
# |43    |Yash    |33 |Bangalore|Director         |125000|2017-08-08  |Management|
# |39    |Teja    |31 |Pune     |Architect        |101000|2018-02-12  |IT        |
# |20    |Ajay    |34 |Chennai  |Lead             |93000 |2018-04-22  |IT        |
# |10    |Vikas   |32 |Pune     |Lead             |91000 |2018-06-30  |IT        |
# |49    |Sandeep |34 |Bangalore|Manager          |97000 |2018-08-15  |Management|
# |33    |Gopi    |32 |Pune     |Lead             |88000 |2019-01-11  |IT        |
# |47    |Lokesh  |30 |Delhi    |Lead             |92000 |2019-05-26  |IT        |
# ...

# %%
# 7. Sort employees by department
df.orderBy("department") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |
# |32    |Kavya   |25 |Chennai  |Analyst          |49000 |2023-05-28  |Analytics |
# |13    |Divya   |24 |Hyderabad|Analyst          |51000 |2023-06-01  |Analytics |
# |42    |Shilpa  |25 |Hyderabad|Analyst          |53000 |2023-03-17  |Analytics |
# |23    |Harsha  |27 |Delhi    |Analyst          |52000 |2022-03-13  |Analytics |
# |35    |Pradeep |30 |Delhi    |Consultant       |82000 |2020-03-23  |Consulting|
# |16    |Mahesh  |33 |Bangalore|Consultant       |87000 |2019-11-19  |Consulting|
# |28    |Sanjana |26 |Mumbai   |Recruiter        |46000 |2021-07-07  |HR        |
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |
# ...

# %%
# 8. Sort employees by designation descending
df.orderBy(df.designation.desc()) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |
# |26    |Neha    |24 |Chennai  |Tester           |50000 |2023-02-18  |QA        |
# |15    |Lavanya |27 |Pune     |Tester           |54000 |2020-08-08  |QA        |
# |36    |Sowmya  |24 |Hyderabad|Tester           |51000 |2022-08-18  |QA        |
# |44    |Reshma  |26 |Chennai  |Tester           |55000 |2022-10-20  |QA        |
# |9     |Pooja   |23 |Chennai  |Support          |40000 |2023-04-19  |Support   |
# |27    |Rohit   |28 |Pune     |Support          |42000 |2022-06-25  |Support   |
# |37    |Chandu  |26 |Bangalore|Support          |41000 |2023-01-30  |Support   |
# |48    |Anu     |23 |Hyderabad|Support          |39000 |2023-07-01  |Support   |
# ...

# %%
# 9. Sort employees first by city then age
df.orderBy("city", "age") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |37    |Chandu  |26 |Bangalore|Support          |41000 |2023-01-30  |Support   |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |31    |Vinay   |29 |Bangalore|Engineer         |67000 |2020-09-19  |IT        |
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# |25    |Tarun   |31 |Bangalore|Developer        |71000 |2021-11-01  |IT        |
# |43    |Yash    |33 |Bangalore|Director         |125000|2017-08-08  |Management|
# |16    |Mahesh  |33 |Bangalore|Consultant       |87000 |2019-11-19  |Consulting|
# |49    |Sandeep |34 |Bangalore|Manager          |97000 |2018-08-15  |Management|
# |9     |Pooja   |23 |Chennai  |Support          |40000 |2023-04-19  |Support   |
# ...

# %%
# 10. Sort employees by salary and limit top 10
df.orderBy(df.salary.desc()) \
  .limit(10) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation|salary|joining_date|department|
# +------+--------+---+---------+-----------+------+------------+----------+
# |43    |Yash    |33 |Bangalore|Director   |125000|2017-08-08  |Management|
# |29    |Manoj   |35 |Delhi    |Director   |120000|2016-12-15  |Management|
# |12    |Ramesh  |35 |Delhi    |Manager    |105000|2017-03-11  |Management|
# |39    |Teja    |31 |Pune     |Architect  |101000|2018-02-12  |IT        |
# |22    |Nikhil  |30 |Mumbai   |Architect  |99000 |2019-07-09  |IT        |
# |8     |Rahul   |31 |Bangalore|Architect  |98000 |2019-10-14  |IT        |
# |49    |Sandeep |34 |Bangalore|Manager    |97000 |2018-08-15  |Management|
# |20    |Ajay    |34 |Chennai  |Lead       |93000 |2018-04-22  |IT        |
# |47    |Lokesh  |30 |Delhi    |Lead       |92000 |2019-05-26  |IT        |
# ...

# %%
# 11. Sort employees by emp_id descending
df.orderBy(df.emp_id.desc()) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |50    |Pallavi |27 |Chennai  |Engineer         |65000 |2020-12-09  |IT        |
# |49    |Sandeep |34 |Bangalore|Manager          |97000 |2018-08-15  |Management|
# |48    |Anu     |23 |Hyderabad|Support          |39000 |2023-07-01  |Support   |
# |47    |Lokesh  |30 |Delhi    |Lead             |92000 |2019-05-26  |IT        |
# |46    |Nikitha |28 |Mumbai   |Developer        |70000 |2021-02-14  |IT        |
# |45    |Abhi    |24 |Pune     |Intern           |26000 |2024-03-11  |Training  |
# |44    |Reshma  |26 |Chennai  |Tester           |55000 |2022-10-20  |QA        |
# |43    |Yash    |33 |Bangalore|Director         |125000|2017-08-08  |Management|
# |42    |Shilpa  |25 |Hyderabad|Analyst          |53000 |2023-03-17  |Analytics |
# ...

# %%
# 12. Sort employees from IT department by salary descending
df.filter(df.department == "IT") \
  .orderBy(df.salary.desc()) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |39    |Teja    |31 |Pune     |Architect        |101000|2018-02-12  |IT        |
# |22    |Nikhil  |30 |Mumbai   |Architect        |99000 |2019-07-09  |IT        |
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# |20    |Ajay    |34 |Chennai  |Lead             |93000 |2018-04-22  |IT        |
# |47    |Lokesh  |30 |Delhi    |Lead             |92000 |2019-05-26  |IT        |
# |10    |Vikas   |32 |Pune     |Lead             |91000 |2018-06-30  |IT        |
# |33    |Gopi    |32 |Pune     |Lead             |88000 |2019-01-11  |IT        |
# |41    |Karthik |27 |Delhi    |Developer        |73000 |2020-11-05  |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# ...

# %%
# 13. Sort employees by joining_date descending
df.orderBy(df.joining_date.desc()) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |45    |Abhi    |24 |Pune     |Intern           |26000 |2024-03-11  |Training  |
# |30    |Asha    |23 |Hyderabad|Intern           |27000 |2024-02-05  |Training  |
# |21    |Bhavana |22 |Pune     |Intern           |25000 |2024-01-10  |Training  |
# |48    |Anu     |23 |Hyderabad|Support          |39000 |2023-07-01  |Support   |
# |13    |Divya   |24 |Hyderabad|Analyst          |51000 |2023-06-01  |Analytics |
# |32    |Kavya   |25 |Chennai  |Analyst          |49000 |2023-05-28  |Analytics |
# |9     |Pooja   |23 |Chennai  |Support          |40000 |2023-04-19  |Support   |
# |42    |Shilpa  |25 |Hyderabad|Analyst          |53000 |2023-03-17  |Analytics |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |
# ...

# %%
# 14. Sort employees alphabetically by emp_name
df.orderBy("emp_name") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |45    |Abhi    |24 |Pune     |Intern           |26000 |2024-03-11  |Training  |
# |20    |Ajay    |34 |Chennai  |Lead             |93000 |2018-04-22  |IT        |
# |11    |Anjali  |26 |Mumbai   |Recruiter        |47000 |2022-02-15  |HR        |
# |48    |Anu     |23 |Hyderabad|Support          |39000 |2023-07-01  |Support   |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# |30    |Asha    |23 |Hyderabad|Intern           |27000 |2024-02-05  |Training  |
# |21    |Bhavana |22 |Pune     |Intern           |25000 |2024-01-10  |Training  |
# |37    |Chandu  |26 |Bangalore|Support          |41000 |2023-01-30  |Support   |
# |24    |Deepika |29 |Hyderabad|Manager          |81000 |2020-10-29  |Management|
# ...

# %%
# 15. Sort employees by multiple columns
df.orderBy("department", df.salary.desc(), "age") \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |42    |Shilpa  |25 |Hyderabad|Analyst          |53000 |2023-03-17  |Analytics |
# |23    |Harsha  |27 |Delhi    |Analyst          |52000 |2022-03-13  |Analytics |
# |13    |Divya   |24 |Hyderabad|Analyst          |51000 |2023-06-01  |Analytics |
# |32    |Kavya   |25 |Chennai  |Analyst          |49000 |2023-05-28  |Analytics |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |
# |16    |Mahesh  |33 |Bangalore|Consultant       |87000 |2019-11-19  |Consulting|
# |35    |Pradeep |30 |Delhi    |Consultant       |82000 |2020-03-23  |Consulting|
# |11    |Anjali  |26 |Mumbai   |Recruiter        |47000 |2022-02-15  |HR        |
# |28    |Sanjana |26 |Mumbai   |Recruiter        |46000 |2021-07-07  |HR        |
# ...

# %%
# LIMIT
# 1. Display first 5 records
df.limit(5) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |
# +------+--------+---+---------+-----------------+------+------------+----------+

# %%
# 2. Display top 10 employees
df.limit(10) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# |9     |Pooja   |23 |Chennai  |Support          |40000 |2023-04-19  |Support   |
# ...

# %%
# 3. Display first 3 employees from IT department
df.filter(df.department == "IT") \
  .limit(3) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# +------+--------+---+---------+-----------------+------+------------+----------+

# %%
# 4. Display top 5 highest salary employees
df.orderBy(df.salary.desc()) \
  .limit(5) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation|salary|joining_date|department|
# +------+--------+---+---------+-----------+------+------------+----------+
# |43    |Yash    |33 |Bangalore|Director   |125000|2017-08-08  |Management|
# |29    |Manoj   |35 |Delhi    |Director   |120000|2016-12-15  |Management|
# |12    |Ramesh  |35 |Delhi    |Manager    |105000|2017-03-11  |Management|
# |39    |Teja    |31 |Pune     |Architect  |101000|2018-02-12  |IT        |
# |22    |Nikhil  |30 |Mumbai   |Architect  |99000 |2019-07-09  |IT        |
# +------+--------+---+---------+-----------+------+------------+----------+

# %%
# 5. Display lowest 5 salary employees
df.orderBy("salary") \
  .limit(5) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation|salary|joining_date|department|
# +------+--------+---+---------+-----------+------+------------+----------+
# |21    |Bhavana |22 |Pune     |Intern     |25000 |2024-01-10  |Training  |
# |45    |Abhi    |24 |Pune     |Intern     |26000 |2024-03-11  |Training  |
# |30    |Asha    |23 |Hyderabad|Intern     |27000 |2024-02-05  |Training  |
# |48    |Anu     |23 |Hyderabad|Support    |39000 |2023-07-01  |Support   |
# |9     |Pooja   |23 |Chennai  |Support    |40000 |2023-04-19  |Support   |
# +------+--------+---+---------+-----------+------+------------+----------+

# %%
# 6. Display first 7 rows after sorting by age
df.orderBy("age") \
  .limit(7) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation|salary|joining_date|department|
# +------+--------+---+---------+-----------+------+------------+----------+
# |21    |Bhavana |22 |Pune     |Intern     |25000 |2024-01-10  |Training  |
# |30    |Asha    |23 |Hyderabad|Intern     |27000 |2024-02-05  |Training  |
# |9     |Pooja   |23 |Chennai  |Support    |40000 |2023-04-19  |Support   |
# |48    |Anu     |23 |Hyderabad|Support    |39000 |2023-07-01  |Support   |
# |3     |Priya   |24 |Chennai  |Analyst    |48000 |2023-03-12  |Analytics |
# |26    |Neha    |24 |Chennai  |Tester     |50000 |2023-02-18  |QA        |
# |13    |Divya   |24 |Hyderabad|Analyst    |51000 |2023-06-01  |Analytics |
# +------+--------+---+---------+-----------+------+------------+----------+

# %%
# 7. Display first 2 employees from Hyderabad
df.filter(df.city == "Hyderabad") \
  .limit(2) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation  |salary|joining_date|department|
# +------+--------+---+---------+-------------+------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer|55000 |2023-01-15  |IT        |
# |7     |Meena   |29 |Hyderabad|Tester       |53000 |2021-12-11  |QA        |
# +------+--------+---+---------+-------------+------+------------+----------+

# %%
# 8. Display first 15 records from dataframe
df.limit(15) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |1     |Sravan  |25 |Hyderabad|Data Engineer    |55000 |2023-01-15  |IT        |
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |3     |Priya   |24 |Chennai  |Analyst          |48000 |2023-03-12  |Analytics |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|
# |5     |Sneha   |27 |Mumbai   |HR               |45000 |2020-05-18  |HR        |
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# |7     |Meena   |29 |Hyderabad|Tester           |53000 |2021-12-11  |QA        |
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# |9     |Pooja   |23 |Chennai  |Support          |40000 |2023-04-19  |Support   |
# ...

# %%
# 9. Display top 5 youngest employees
df.orderBy("age") \
  .limit(5) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation|salary|joining_date|department|
# +------+--------+---+---------+-----------+------+------------+----------+
# |21    |Bhavana |22 |Pune     |Intern     |25000 |2024-01-10  |Training  |
# |30    |Asha    |23 |Hyderabad|Intern     |27000 |2024-02-05  |Training  |
# |9     |Pooja   |23 |Chennai  |Support    |40000 |2023-04-19  |Support   |
# |48    |Anu     |23 |Hyderabad|Support    |39000 |2023-07-01  |Support   |
# |3     |Priya   |24 |Chennai  |Analyst    |48000 |2023-03-12  |Analytics |
# +------+--------+---+---------+-----------+------+------------+----------+

# %%
# 10. Display first 8 employees after filtering salary > 60000
df.filter(df.salary > 60000) \
  .limit(8) \
  .show(500, truncate=False)
# Out:
# +------+--------+---+---------+-----------------+------+------------+----------+
# |emp_id|emp_name|age|city     |designation      |salary|joining_date|department|
# +------+--------+---+---------+-----------------+------+------------+----------+
# |2     |Ravi    |28 |Bangalore|Software Engineer|72000 |2022-11-10  |IT        |
# |4     |Kiran   |30 |Pune     |Manager          |85000 |2021-09-20  |Management|
# |6     |Arjun   |26 |Delhi    |Developer        |61000 |2022-07-25  |IT        |
# |8     |Rahul   |31 |Bangalore|Architect        |98000 |2019-10-14  |IT        |
# |10    |Vikas   |32 |Pune     |Lead             |91000 |2018-06-30  |IT        |
# |12    |Ramesh  |35 |Delhi    |Manager          |105000|2017-03-11  |Management|
# |14    |Suresh  |29 |Chennai  |Developer        |68000 |2021-01-21  |IT        |
# |16    |Mahesh  |33 |Bangalore|Consultant       |87000 |2019-11-19  |Consulting|
# +------+--------+---+---------+-----------------+------+------------+----------+
